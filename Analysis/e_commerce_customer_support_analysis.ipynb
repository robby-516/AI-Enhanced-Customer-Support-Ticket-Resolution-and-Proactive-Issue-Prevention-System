# %%
# Import necessary libraries
import pandas as pd
import requests

# Load the dataset
dataset_url = "hf://datasets/NebulaByte/E-Commerce_Customer_Support_Conversations/data/train-00000-of-00001-a5a7c6e4bb30b016.parquet"
df = pd.read_parquet(dataset_url)

# Preview dataset structure
print("Dataset Structure:")
print(df.info())
# print("\nSample Data:")
# print(df.head())

# Derive top 3 insights
# Insight 1: Distribution of issue complexities
issue_complexity_distribution = df['issue_complexity'].value_counts()
print("\nInsight 1: Issue Complexity Distribution")
print(issue_complexity_distribution)

# Insight 2: Correlation between agent experience level and issue complexity
agent_experience_correlation = df.groupby(['agent_experience_level', 'issue_complexity']).size().unstack(fill_value=0)
print("\nInsight 2: Agent Experience Level vs Issue Complexity")
print(agent_experience_correlation)

# Insight 3: Customer sentiment distribution across issue categories
sentiment_category_distribution = df.groupby(['customer_sentiment', 'issue_category']).size().unstack(fill_value=0)
print("\nInsight 3: Customer Sentiment Distribution by Issue Category")
print(sentiment_category_distribution)
# Out:
# Dataset Structure:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   issue_area                   1000 non-null   object
#  1   issue_category               1000 non-null   object
#  2   issue_sub_category           1000 non-null   object
#  3   issue_category_sub_category  1000 non-null   object
#  4   customer_sentiment           1000 non-null   object
#  5   product_category             1000 non-null   object
#  6   product_sub_category         1000 non-null   object
#  7   issue_complexity             1000 non-null   object
#  8   agent_experience_level       1000 non-null   object
#  9   agent_experience_level_desc  1000 non-null   object
#  10  conversation                 1000 non-null   object
# dtypes: object(11)
# memory usage: 86.1+ KB
# None
#
# Insight 1: Issue Complexity Distribution
# issue_complexity
# less      488
# medium    426
# high       86
# Name: count, dtype: int64
#
# Insight 2: Agent Experience Level vs Issue Complexity
# issue_complexity        high  less  medium
# agent_experience_level
# experienced               31   171     146
# inexperienced              9    71      65
# junior                    46   246     215
#
# Insight 3: Customer Sentiment Distribution by Issue Category
# issue_category      Accessing Warranty Details  \
# customer_sentiment
# frustrated                                   0
# negative                                     0
# neutral                                     15
# positive                                     0
#
# issue_category      Account Reactivation and Deactivation  \
# customer_sentiment
# frustrated                                              0
# negative                                               14
# neutral                                                 6
# positive                                                0
#
# issue_category      Account and Shopping  \
# customer_sentiment
# frustrated                             0
# negative                               6
# neutral                               20
# positive                               0
#
# issue_category      Adding and Changing Account Information  \
# customer_sentiment
# frustrated                                                0
# negative                                                  0
# neutral                                                  24
# positive                                                  0
#
# issue_category      Availability of Faster Delivery Options  \
# customer_sentiment
# frustrated                                                0
# negative                                                 18
# neutral                                                   0
# positive                                                  0
#
# issue_category      Book Pricing Discrepancies  \
# customer_sentiment
# frustrated                                   0
# negative                                     0
# neutral                                     10
# positive                                     0
#
# issue_category      Cash on Delivery (CoD) Refunds  \
# customer_sentiment
# frustrated                                      12
# negative                                         9
# neutral                                          8
# positive                                         0
#
# issue_category      Contacting Seller's Partnered Courier Service Providers  \
# customer_sentiment
# frustrated                                                          0
# negative                                                            0
# neutral                                                             5
# positive                                                            0
#
# issue_category      Delivery Process  Expedited Delivery  ...  \
# customer_sentiment                                        ...
# frustrated                         0                   0  ...
# negative                           0                   0  ...
# neutral                            6                  12  ...
# positive                           0                   0  ...
#
# issue_category      Product Registration and Warranty  \
# customer_sentiment
# frustrated                                          0
# negative                                            3
# neutral                                             8
# positive                                            0
#
# issue_category      Replacement and Return Process  Return Checks and Fees  \
# customer_sentiment
# frustrated                                       0                       0
# negative                                        11                      12
# neutral                                         47                      16
# positive                                         0                       0
#
# issue_category      Return and Exchange  Returns and Refunds  \
# customer_sentiment
# frustrated                           20                    9
# negative                             35                   20
# neutral                              40                    8
# positive                              0                    0
#
# issue_category      Shipping Options for Returns  \
# customer_sentiment
# frustrated                                     0
# negative                                       0
# neutral                                       10
# positive                                       0
#
# issue_category      Standard Shipping Speeds and Delivery Charges  \
# customer_sentiment
# frustrated                                                      0
# negative                                                        7
# neutral                                                         8
# positive                                                        0
#
# issue_category      Start Date of Warranty  Warranty Claim Process  \
# customer_sentiment
# frustrated                               0                       0
# negative                                 0                       0
# neutral                                  9                      17
# positive                                 0                       0
#
# issue_category      Warranty Terms and Changes
# customer_sentiment
# frustrated                                   0
# negative                                     5
# neutral                                      8
# positive                                     0
#
# [4 rows x 40 columns]

# %%
# prompt: give an apt name for the program above

e_commerce_customer_support_analysis.py
